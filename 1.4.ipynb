# %% [markdown]
# ##### Installation of Git

# %% [markdown]
# ## Done ✅

# %% [markdown]
# ##### Creating GitHub Account

# %% [markdown]
# ## Done ✅

# %% [markdown]
# ##### Create a GitHub Repository

# %% [markdown]
# ## Done ✅

# %% [markdown]
# ### Push on GitHub (Upload Local Project)

# %% [markdown]
# ##### 1. git init
# ##### 2. git add (filename)  OR git add .  (#add all the files)
# ##### 3. git commit -m "commited"
# ##### 4. git remote add origin (git repository path)
# ##### 5. git branch -M main/master
# ##### 6. git push -u origin main/master

# %% [markdown]
# ### Pull from GitHub

# %% [markdown]
# ##### 1. git remote -v
# ##### 2. git pull origin main/master
# ##### 3. git pull

# %% [markdown]
# #### Python Installation

# %% [markdown]
# ### Done ✅

# %% [markdown]
# #### Print the pattern

# %%
print("*")
print("**")
print("***")
print("**")
print("*")
# Out:
# *
# **
# ***
# **
# *
